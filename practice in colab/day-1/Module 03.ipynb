# %%
import pandas as pd

# %%
data = [(1,2),(3,4),(5,6)]
data
# Out:
# [(1, 2), (3, 4), (5, 6)]

# %%
df = pd.DataFrame(data,columns=['num1','num2'])

# %%
df
# Out:
#    num1  num2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
s = df[['num1','num2']]

# %%
print(s)
# Out:
#    num1  num2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
print(type(s))
# Out:
# <class 'pandas.core.frame.DataFrame'>
