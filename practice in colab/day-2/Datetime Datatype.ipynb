# %%
import pandas as pd

# %%
dates = ['2026-05-01', '2026-06-02']

# %%
df = pd.DataFrame({'Date' : dates})

# %%
print(df)
print(df['Date'].dtype)
# Out:
#          Date
# 0  2026-05-01
# 1  2026-06-02
# object

# %%
timestamps = pd.to_datetime(dates)
df2 = pd.DataFrame({'Date2': timestamps})

# %%
print(df2)
print(df2.info())
print(df2['Date2'].dtype)
# Out:
#        Date2
# 0 2026-05-01
# 1 2026-06-02
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date2   2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 148.0 bytes
# None
# datetime64[ns]

# %%
# Create a list of dates
dates = ['2026', '2026-05-01', '2027']
df1 = pd.DataFrame({'Date' : dates})

timestamps = pd.to_datetime(dates,format='%Y', errors='coerce')
df2 = pd.DataFrame({'Date2': timestamps})

# %%
df1['Date'].dtype
# Out:
# dtype('O')

# %%
df2['Date2'].dtype
# Out:
# dtype('<M8[ns]')

# %%
print(df2)
# Out:
#        Date2
# 0 2026-01-01
# 1        NaT
# 2 2027-01-01
