# %%
import pandas as pd

# %%
data = {
    'Name':['John','Jane','Bob','Alice'],
    'Age':[25,30,35,40],
    'Occupation':['Data Scientist', 'Software Engineer', 'Teacher', 'Developer'],
    'Salary':[50000,60000,70000,80000]
}

# %%
data
# Out:
# {'Name': ['John', 'Jane', 'Bob', 'Alice'],
#  'Age': [25, 30, 35, 40],
#  'Occupation': ['Data Scientist', 'Software Engineer', 'Teacher', 'Developer'],
#  'Salary': [50000, 60000, 70000, 80000]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Name  Age         Occupation  Salary
# 0   John   25     Data Scientist   50000
# 1   Jane   30  Software Engineer   60000
# 2    Bob   35            Teacher   70000
# 3  Alice   40          Developer   80000

# %%
print(df.dtypes)
# Out:
# Name          object
# Age            int64
# Occupation    object
# Salary         int64
# dtype: object
