# %%
import pandas as pd

# %%
data = {
    'name':['Shefaul', 'Rakib', 'Shimul'],
    'age' : [24, 23, 25],
    'city' : ['Nilphamari', 'Dinajpur', 'Chuadanga']
}

# %%
data
# Out:
# {'name': ['Shefaul', 'Rakib', 'Shimul'],
#  'age': [24, 23, 25],
#  'city': ['Nilphamari', 'Dinajpur', 'Chuadanga']}

# %%
name_series = data['name']

# %%
type(name_series)
# Out:
# list

# %%
name_series = pd.Series(data['name'], name = 'Name')

# %%
name_series
# Out:
# 0    Shefaul
# 1      Rakib
# 2     Shimul
# Name: Name, dtype: object

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age        city
# 0  Shefaul   24  Nilphamari
# 1    Rakib   23    Dinajpur
# 2   Shimul   25   Chuadanga

# %%
age_series = pd.Series(data['age'], name = 'Age')

# %%
age_series
# Out:
# 0    24
# 1    23
# 2    25
# Name: Age, dtype: int64
