# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/data1.xlsx')

# %%
print(df)
# Out:
#    Srl. No.  Marks
# 0         1     80
# 1         2     75
# 2         3     78
# 3         4     68
# 4         5     62

# %%
df1 = pd.read_excel('/content/drive/My Drive/Colab Notebooks/data1.xlsx', sheet_name = 'Salary')

# %%
print(df1)
# Out:
#       Name  Sealary
# 0  Shefaul    50000
# 1   Tanvir    45000
# 2   Towfiq    40000
# 3    Sajol    35000
# 4   Sabbir    25000

# %%
df2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data1.csv')

# %%
print(df2)
# Out:
#      Name  Age        City  Salary
# 0  Tanvir   25  Thakurgaon   45000
# 1   Sajol   24       Pabna   40000
# 2   Shefa   25  Nilphamari   50000
# 3  Towfiq   23    Dinajpur   35000
