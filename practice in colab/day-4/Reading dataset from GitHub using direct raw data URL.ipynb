# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/shefa19/pandas-practice/refs/heads/main/day_6/student_practice.csv'

# %%
df = pd.read_csv(url)

# %%
print(df.head())
# Out:
#     ID    Name  Age Department  CGPA
# 0  101   Rahim   23        CSE   3.5
# 1  102   Karim   25        EEE   3.2
# 2  103  Ayesha   22        BBA   3.8
# 3  104   Salma   24        CSE   3.6
# 4  105   Jamil   26    English   3.1
